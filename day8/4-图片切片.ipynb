# %%
import numpy as np
from PIL import Image
im = Image.open('test.png')
imarr = np.array(im)
imarr
# Out:
# array([[[230, 230, 230, 255],
#         [228, 228, 228, 255],
#         [227, 227, 227, 255],
#         ...,
#         [225, 225, 225, 255],
#         [226, 226, 226, 255],
#         [228, 228, 228, 255]],
#
#        [[228, 228, 228, 255],
#         [227, 227, 227, 255],
#         [227, 227, 227, 255],
#         ...,
#         [225, 225, 225, 255],
#         [225, 225, 225, 255],
#         [226, 226, 226, 255]],
#
#        [[227, 227, 227, 255],
#         [226, 226, 226, 255],
#         [206, 206, 206, 255],
#         ...,
#         [204, 204, 204, 255],
#         [225, 225, 225, 255],
#         [225, 225, 225, 255]],
#
#        ...,
#
#        [[208, 208, 208, 255],
#         [206, 206, 206, 255],
#         [205, 205, 205, 255],
#         ...,
#         [205, 205, 205, 255],
#         [206, 206, 206, 255],
#         [208, 208, 208, 255]],
#
#        [[208, 208, 208, 255],
#         [207, 207, 207, 255],
#         [205, 205, 205, 255],
#         ...,
#         [205, 205, 205, 255],
# ...

# %%
small_arr = imarr[::5,::5]
Image.fromarray(small_arr)
# Out:
# <PIL.Image.Image image mode=RGBA size=318x177 at 0x195283F7EF0>

# %%
Image.fromarray(imarr[::-1,::-1])
# Out:
# <PIL.Image.Image image mode=RGBA size=1589x881 at 0x19528419080>

# %%
Image.fromarray(imarr[::-1,::-1]+imarr)
# Out:
# <PIL.Image.Image image mode=RGBA size=1589x881 at 0x1952A150080>

# %%
imarr.max(axis = 0)
# Out:
# array([[247, 247, 247, 255],
#        [247, 247, 247, 255],
#        [247, 247, 247, 255],
#        ...,
#        [247, 247, 247, 255],
#        [247, 247, 247, 255],
#        [247, 247, 247, 255]], dtype=uint8)

# %%
imarr.max(axis =1)
# Out:
# array([[230, 230, 230, 255],
#        [228, 228, 228, 255],
#        [227, 227, 227, 255],
#        ...,
#        [241, 241, 241, 255],
#        [208, 208, 208, 255],
#        [209, 209, 209, 255]], dtype=uint8)

# %% [markdown]
# ### axis = 0:沿着行的方向
# ### axis = 1:沿着列的方向

# %%
arr = np.array([[1,2,3],[12,1,32]])
arr.max(axis=0) ## arr.min()
# Out:
# array([12,  2, 32])

# %%
arr.max(axis=1)
# Out:
# array([ 3, 32])
